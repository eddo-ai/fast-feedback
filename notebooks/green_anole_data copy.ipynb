# %% [markdown]
# ## Load Student Responses

# %%
# Load to dataframe: data/green_anole/enriched_data_20250501_215017.csv
import pandas as pd

# Load the CSV file into a pandas DataFrame
df = pd.read_csv('/Users/aw/Developer/wauwatosa/data/green_anole/Wauwatosa Grade 8 Assessment_ Green Anole Lizard (Responses) - Form Responses 20250506 filtered.csv')

df
# Out:
# Shape of the DataFrame: (3, 7)
#
# First few rows of the DataFrame:
#              Timestamp                     Email Address  \
# 0  2025-05-02 07:54:27  rommelma2029@wauwatosa.k12.wi.us
# 1  2025-05-02 08:29:45   greerlo2029@wauwatosa.k12.wi.us
# 2  2025-05-02 12:09:56  riordasa2029@wauwatosa.k12.wi.us
#
#                    Name  Teacher Name    Hour  \
# 0  Matthew Rommelfanger  Mr. Kitzerow  Hour 3
# 1          London greer  Mr. Kitzerow  Hour 3
# 2          Sam Riordan    Mr. Summers  Hour 6
#
#   1. What do you notice about the behavior and body structures of the green lizards who live on islands with brown lizards versus the green lizards who live on islands with no brown lizards?  \
# 0  \nI notice a change in average perch height in...
# 1  while the lizards who are on an island without...
# 2  The islands with brown lizards, had higher fro...
#
#   2. Construct an explanation: How does natural selection explain the changes in the green lizard population over time?\n- Take out your Copy of Our General  Model\n- Use the key parts of the General Model to explain the cause and effect of the changes in the green lizard population over time.\nIn your explanation make sure to include the following:\n  - the key parts of the model\n  - cause and effect to describe how the population changed over time\n - the data about the green and brown lizard populations that support your explanation
# 0  Natural selection explains the changes in gree...
# 1  The green lizards who are on an island with th...
# 2  Claim: The lizards are changing through natura...
#              Timestamp                     Email Address  \
# 0  2025-05-02 07:54:27  rommelma2029@wauwatosa.k12.wi.us
# 1  2025-05-02 08:29:45   greerlo2029@wauwatosa.k12.wi.us
# 2  2025-05-02 12:09:56  riordasa2029@wauwatosa.k12.wi.us
#
#                    Name  Teacher Name    Hour  \
# 0  Matthew Rommelfanger  Mr. Kitzerow  Hour 3
# 1          London greer  Mr. Kitzerow  Hour 3
# 2          Sam Riordan    Mr. Summers  Hour 6
#
#   1. What do you notice about the behavior and body structures of the green lizards who live on islands with brown lizards versus the green lizards who live on islands with no brown lizards?  \
# 0  \nI notice a change in average perch height in...
# 1  while the lizards who are on an island without...
# 2  The islands with brown lizards, had higher fro...
#
#   2. Construct an explanation: How does natural selection explain the changes in the green lizard population over time?\n- Take out your Copy of Our General  Model\n- Use the key parts of the General Model to explain the cause and effect of the changes in the green lizard population over time.\nIn your explanation make sure to include the following:\n  - the key parts of the model\n  - cause and effect to describe how the population changed over time\n - the data about the green and brown lizard populations that support your explanation
# 0  Natural selection explains the changes in gree...
# 1  The green lizards who are on an island with th...
# 2  Claim: The lizards are changing through natura...

# %% [markdown]
# ## Merge with AI Feedback

# %%
# Load JSON files
import json

# Define email mapping
email_mapping = {
    'rommelma2029@wauwatosa.k12.wi.us': 'matthew.json',
    'greerlo2029@wauwatosa.k12.wi.us': 'london_greer.json',
    'riordasa2029@wauwatosa.k12.wi.us': 'sam_riordan.json'
}

# Initialize empty lists to store data
data = []

# Load and process each JSON file
for email, json_file in email_mapping.items():
    with open(f'data/green_anole/{json_file}', 'r') as f:
        json_data = json.load(f)
        
        # Extract data
        row_data = {
            'Email Address': email,
            'teacher_notes': None,
            'teacher_score': None,
            'finalized': None,
            'last_modified': None,
            'ai_annotated_response': json_data['annotated_response'],
            'ai_score_SEP': json_data['rubric_scores']['SEP'],
            'ai_score_DCI': json_data['rubric_scores']['DCI'],
            'ai_score_CCC': json_data['rubric_scores']['CCC'],
            'ai_score_Communication': json_data['rubric_scores']['Communication'],
            'ai_score_Overall': json_data['rubric_scores']['Overall'],
            'ai_feedback_strengths': json_data['feedback']['strengths'],
            'ai_feedback_suggestions': json_data['feedback']['suggestions']
        }
        data.append(row_data)

# Create DataFrame
feedback_df = pd.DataFrame(data)

# Display information about the feedback DataFrame
print("Feedback DataFrame shape:", feedback_df.shape)
print("\nFeedback DataFrame columns:")
print(feedback_df.columns)

feedback_df
# Out:
# Feedback DataFrame shape: (3, 13)
#
# Feedback DataFrame columns:
# Index(['Email Address', 'teacher_notes', 'teacher_score', 'finalized',
#        'last_modified', 'ai_annotated_response', 'ai_score_SEP',
#        'ai_score_DCI', 'ai_score_CCC', 'ai_score_Communication',
#        'ai_score_Overall', 'ai_feedback_strengths', 'ai_feedback_suggestions'],
#       dtype='object')
#                       Email Address teacher_notes teacher_score finalized  \
# 0  rommelma2029@wauwatosa.k12.wi.us          None          None      None
# 1   greerlo2029@wauwatosa.k12.wi.us          None          None      None
# 2  riordasa2029@wauwatosa.k12.wi.us          None          None      None
#
#   last_modified                              ai_annotated_response  \
# 0          None  **Part 1:**\n\nI notice a change in average pe...
# 1          None  **Part 1:**\nWhile the lizards who are on an i...
# 2          None  **Part 1:**  \nThe islands with **_brown lizar...
#
#    ai_score_SEP  ai_score_DCI  ai_score_CCC  ai_score_Communication  \
# 0             3             3             3                       3
# 1             3             3             2                       3
# 2             3             3             3                       3
#
#    ai_score_Overall                              ai_feedback_strengths  \
# 0                 3  - You clearly explained how green lizards adap...
# 1                 3  - **Great use of quantitative data** (e.g., av...
# 2                 3  - You effectively included key elements of the...
#
#                              ai_feedback_suggestions
# 0  - Focus on improving the **clarity of your exp...
# 1  - **Explicitly connect trait variations, envir...
# 2  - Improve the **structure** of your response b...

# %%
# Load and merge feedback data on Email Address
# Merge feedback data with original data on Email Address
merged_df = pd.merge(df, feedback_df, on='Email Address', how='left')

merged_df
# Out:
#              Timestamp                     Email Address  \
# 0  2025-05-02 07:54:27  rommelma2029@wauwatosa.k12.wi.us
# 1  2025-05-02 08:29:45   greerlo2029@wauwatosa.k12.wi.us
# 2  2025-05-02 12:09:56  riordasa2029@wauwatosa.k12.wi.us
#
#                    Name  Teacher Name    Hour  \
# 0  Matthew Rommelfanger  Mr. Kitzerow  Hour 3
# 1          London greer  Mr. Kitzerow  Hour 3
# 2          Sam Riordan    Mr. Summers  Hour 6
#
#   1. What do you notice about the behavior and body structures of the green lizards who live on islands with brown lizards versus the green lizards who live on islands with no brown lizards?  \
# 0  \nI notice a change in average perch height in...
# 1  while the lizards who are on an island without...
# 2  The islands with brown lizards, had higher fro...
#
#   2. Construct an explanation: How does natural selection explain the changes in the green lizard population over time?\n- Take out your Copy of Our General  Model\n- Use the key parts of the General Model to explain the cause and effect of the changes in the green lizard population over time.\nIn your explanation make sure to include the following:\n  - the key parts of the model\n  - cause and effect to describe how the population changed over time\n - the data about the green and brown lizard populations that support your explanation  \
# 0  Natural selection explains the changes in gree...
# 1  The green lizards who are on an island with th...
# 2  Claim: The lizards are changing through natura...
#
#   teacher_notes teacher_score finalized last_modified  \
# 0          None          None      None          None
# 1          None          None      None          None
# 2          None          None      None          None
#
#                                ai_annotated_response  ai_score_SEP  \
# 0  **Part 1:**\n\nI notice a change in average pe...             3
# 1  **Part 1:**\nWhile the lizards who are on an i...             3
# 2  **Part 1:**  \nThe islands with **_brown lizar...             3
#
#    ai_score_DCI  ai_score_CCC  ai_score_Communication  ai_score_Overall  \
# 0             3             3                       3                 3
# 1             3             2                       3                 3
# 2             3             3                       3                 3
#
#                                ai_feedback_strengths  \
# 0  - You clearly explained how green lizards adap...
# 1  - **Great use of quantitative data** (e.g., av...
# 2  - You effectively included key elements of the...
#
#                              ai_feedback_suggestions
# 0  - Focus on improving the **clarity of your exp...
# 1  - **Explicitly connect trait variations, envir...
# 2  - Improve the **structure** of your response b...

# %% [markdown]
# ## Save to new file

# %%
merged_df.to_csv('data/green_anole/green_anole_data_may_6.csv', index=False)

# %% [markdown]
# ## Generate a sample PDF for one student

# %%
# Configuration
DISPLAY_OPTIONS = {
    "show_teacher_score": True,  # Set to False to hide teacher scores
    "show_teacher_notes": True,  # Set to False to hide teacher notes
    "show_ai_feedback": True,  # Set to False to hide AI feedback
}

# Load required libraries
import pandas as pd
import numpy as np
from fpdf import FPDF, HTMLMixin
import markdown
from datetime import datetime
import re
import os


def clean_text(text):
    """Clean text of special characters that might cause issues."""
    if pd.isna(text):
        return ""

    # Convert to string
    text = str(text)

    # Replace problematic characters
    replacements = {
        "—": "-",  # em dash
        "–": "-",  # en dash
        """: '"',  # smart quotes
        """: '"',
        "'": "'",  # smart apostrophes
        "'": "'",
        "…": "...",  # ellipsis
        "\u2019": "'",  # right single quotation mark
        "\u2018": "'",  # left single quotation mark
        "\u201C": '"',  # left double quotation mark
        "\u201D": '"',  # right double quotation mark
        "\u2013": "-",  # en dash
        "\u2014": "-",  # em dash
        "\u2026": "...",  # horizontal ellipsis
    }

    for old, new in replacements.items():
        text = text.replace(old, new)

    # Remove any other non-ASCII characters
    text = "".join(char if ord(char) < 128 else " " for char in text)

    return text


class StudentReportPDF(FPDF, HTMLMixin):
    def __init__(self, teacher_name="", hour=""):
        # Use landscape orientation with narrow margins for compact layout
        super().__init__(orientation="L", unit="mm", format="Letter")
        self.teacher_name = teacher_name
        self.hour = hour
        # Narrow margins and tighter page break
        self.set_margins(left=10, top=10, right=10)
        self.set_auto_page_break(auto=True, margin=10)

    def header(self):
        # Add header with title, teacher, hour and date
        self.set_font("Helvetica", "B", 15)
        self.cell(
            0,
            8,
            "Student Response Analysis",
            border=0,
            new_x="LMARGIN",
            new_y="NEXT",
        )
        self.set_font("Helvetica", "", 12)
        self.cell(
            0,
            6,
            f"{self.teacher_name} - {self.hour}",
            border=0,
            new_x="LMARGIN",
            new_y="NEXT",
        )
        self.set_font("Helvetica", "", 10)
        self.cell(
            0,
            4,
            datetime.now().strftime("%Y-%m-%d"),
            border=0,
            new_x="LMARGIN",
            new_y="NEXT",
        )
        self.ln(5)

    def footer(self):
        # Add page numbers
        self.set_y(-15)
        self.set_font("Helvetica", "I", 8)
        self.cell(
            0,
            10,
            f"Page {self.page_no()}",
            border=0,
            new_x="RIGHT",
            new_y="TOP",
            align="C",
        )

    def add_section_title(self, title, size=12):
        # Smaller title font for compactness
        self.set_font("Helvetica", "B", size - 1)
        self.set_fill_color(240, 240, 240)  # Light gray background
        self.cell(
            0,
            6,
            clean_text(title),
            border=0,
            new_x="LMARGIN",
            new_y="NEXT",
            align="L",
            fill=True,
        )
        self.ln(1)

    def add_content(self, content, size=11):
        """Render markdown-formatted text content in the PDF."""
        # Clean text and convert markdown to HTML
        content_str = clean_text(content)
        html = markdown.markdown(content_str)
        # Tighter content spacing
        self.set_font("Helvetica", "", size - 1)
        self.write_html(html)
        self.ln(3)


def create_student_reports(df):
    # Create output directory if it doesn't exist
    output_dir = "student_reports"
    os.makedirs(output_dir, exist_ok=True)

    # Group the DataFrame by teacher and hour
    grouped = df.groupby(["Teacher Name", "Hour"])

    for (teacher_name, hour), group_df in grouped:
        # Create a sanitized filename
        safe_teacher_name = re.sub(r"[^\w\s-]", "", teacher_name).strip()
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        output_file = os.path.join(
            output_dir, f"{safe_teacher_name}_Hour_{hour}_reports_{timestamp}.pdf"
        )

        pdf = StudentReportPDF(teacher_name=teacher_name, hour=hour)

        for _, student_row in group_df.iterrows():
            pdf.add_page()

            # Student Name and Email
            student_name = student_row["Name"] if "Name" in student_row else "Unknown"
            pdf.add_section_title(f"Student: {student_name}", 14)
            pdf.add_content(f"Email: {student_row['Email Address']}")
            pdf.ln(5)

            # Annotated Response
            pdf.add_section_title("Annotated Response:")
            pdf.add_content(student_row["ai_annotated_response"])

            # Teacher Notes (if enabled and exists)
            if DISPLAY_OPTIONS["show_teacher_notes"]:
                teacher_notes = student_row["teacher_notes"]
                if pd.notna(teacher_notes) and str(teacher_notes).strip():
                    pdf.add_section_title(f"Notes from {teacher_name}:")
                    pdf.add_content(teacher_notes)

            # Teacher Score (if enabled and exists)
            if DISPLAY_OPTIONS["show_teacher_score"]:
                teacher_score = (
                    student_row["teacher_score"]
                    if "teacher_score" in df.columns
                    else None
                )
                if pd.notna(teacher_score):
                    pdf.add_section_title("Teacher Score:")
                    pdf.add_content(str(teacher_score))

            # AI Feedback (if enabled)
            if DISPLAY_OPTIONS["show_ai_feedback"]:
                pdf.add_section_title("AI Feedback:")

                # Strengths
                pdf.set_font("Helvetica", "B", 11)
                pdf.cell(
                    0,
                    7,
                    "Strengths:",
                    border=0,
                    new_x="LMARGIN",
                    new_y="NEXT",
                    align="L",
                )
                pdf.add_content(student_row["ai_feedback_strengths"])

                # Suggestions
                pdf.set_font("Helvetica", "B", 11)
                pdf.cell(
                    0,
                    7,
                    "Suggestions for Improvement:",
                    border=0,
                    new_x="LMARGIN",
                    new_y="NEXT",
                    align="L",
                )
                pdf.add_content(student_row["ai_feedback_suggestions"])

        # Save the document
        pdf.output(output_file)
        print(f"PDF report has been generated: {output_file}")

# %%
df = merged_df
# Create the reports
create_student_reports(df)

# Print summary information
print("\nSummary of reports generated:")
grouped_summary = df.groupby(["Teacher Name", "Hour"]).size()
for (teacher, hour), count in grouped_summary.items():
    print(f"{teacher} - {hour}: {count} students")
# Out:
# PDF report has been generated: student_reports/Mr Kitzerow_Hour_Hour 3_reports_20250506_151253.pdf
# PDF report has been generated: student_reports/Mr Summers_Hour_Hour 6_reports_20250506_151253.pdf
#
# Summary of reports generated:
# Mr. Kitzerow - Hour 3: 2 students
# Mr. Summers - Hour 6: 1 students
# /var/folders/3z/syzrc_jj20j788v5f0yrmkwr0000gn/T/ipykernel_60443/718490164.py:56: DeprecationWarning: The HTMLMixin class is deprecated since v2.6.0. Simply use the FPDF class as a replacement.
#   super().__init__(orientation="L", unit="mm", format="Letter")

# %% [markdown]
# ## Generate multipage files for each hour, teacher.
